# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the random module.
import random 
# Import the time module.
import time
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 602

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9c46a9f1a17d6c95a3825735e927c1cf

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description=city_weather["weather"][0]["description"]
        try:
            city_rain=city_weather["rain"]["3h"] 
        except KeyError:    
            city_rain=0
        try: 
            city_snow=city_weather["snow"]["3h"]
        except KeyError:
            city_snow=0
        
            
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Rain(inches)": city_rain,
                          "Snow(inches)":city_snow})
      
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kormilovka
# Processing Record 2 of Set 1 | new norfolk
# Processing Record 3 of Set 1 | omsukchan
# Processing Record 4 of Set 1 | gamba
# Processing Record 5 of Set 1 | luwuk
# Processing Record 6 of Set 1 | glace bay
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | scarborough
# Processing Record 9 of Set 1 | las vegas
# Processing Record 10 of Set 1 | nelson bay
# Processing Record 11 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 12 of Set 1 | mar del plata
# Processing Record 13 of Set 1 | san cristobal
# Processing Record 14 of Set 1 | torbay
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | namibe
# Processing Record 18 of Set 1 | airai
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | ostrovnoy
# Processing Record 21 of Set 1 | souillac
# Processing Record 22 of Set 1 | shieli
# Processing Record 23 of Set 1 | kahului
# Processing Record 24 of Set 1 | hue
# Processing Record 25 of Set 1 | paucartambo
# City not found. Skipping...
# Processing Record 26 of Set 1 | port blair
# Processing Record 27 of Set 1 | vagur
# Processing Record 28 of Set 1 | tuktoyaktuk
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | kaitangata
# Processing Record 31 of Set 1 | high level
# Processing Record 32 of Set 1 | monte alegre de sergipe
# Processing Record 33 of Set 1 | rudraprayag
# Processing Record 34 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 1 | vestmannaeyjar
# Processing Record 36 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 1 | vanimo
# Processing Record 38 of Set 1 | lisakovsk
# Processing Record 39 of Set 1 | tiksi
# Processing Record 40 of Set 1 | butaritari
# Processing Record 41 of Set 1 | portland
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | langsa
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | saldanha
# Processing Record 46 of Set 1 | castro
# Processing Record 47 of Set 1 | shahreza
# Processing Record 48 of Set 1 | ye
# City not found. Skipping...
# Processing Record 49 of Set 1 | gashua
# Processing Record 50 of Set 1 | bandarbeyla
# Processing Record 1 of Set 2 | rikitea
# Processing Record 2 of Set 2 | simpang
# Processing Record 3 of Set 2 | carnarvon
# Processing Record 4 of Set 2 | avarua
# Processing Record 5 of Set 2 | miri
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | cape town
# Processing Record 8 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 2 | hithadhoo
# Processing Record 10 of Set 2 | sao joao da barra
# Processing Record 11 of Set 2 | ushuaia
# Processing Record 12 of Set 2 | port elizabeth
# Processing Record 13 of Set 2 | bathsheba
# Processing Record 14 of Set 2 | zacualpan
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | ulaanbaatar
# Processing Record 17 of Set 2 | hasaki
# Processing Record 18 of Set 2 | saint-augustin
# Processing Record 19 of Set 2 | aswan
# Processing Record 20 of Set 2 | ribeira grande
# Processing Record 21 of Set 2 | grand gaube
# Processing Record 22 of Set 2 | benghazi
# Processing Record 23 of Set 2 | greenfield
# Processing Record 24 of Set 2 | khatanga
# Processing Record 25 of Set 2 | inongo
# Processing Record 26 of Set 2 | barrow
# Processing Record 27 of Set 2 | alofi
# Processing Record 28 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 2 | blagodarnyy
# Processing Record 30 of Set 2 | lebu
# Processing Record 31 of Set 2 | manaus
# Processing Record 32 of Set 2 | waipawa
# Processing Record 33 of Set 2 | tarpon springs
# Processing Record 34 of Set 2 | atuona
# Processing Record 35 of Set 2 | roros
# Processing Record 36 of Set 2 | severo-kurilsk
# Processing Record 37 of Set 2 | goderich
# Processing Record 38 of Set 2 | arraial do cabo
# Processing Record 39 of Set 2 | stornoway
# Processing Record 40 of Set 2 | kruisfontein
# Processing Record 41 of Set 2 | kapaa
# Processing Record 42 of Set 2 | usolye
# Processing Record 43 of Set 2 | turkistan
# Processing Record 44 of Set 2 | saint-jovite
# Processing Record 45 of Set 2 | mataura
# Processing Record 46 of Set 2 | yellowknife
# Processing Record 47 of Set 2 | saint-pierre
# Processing Record 48 of Set 2 | talnakh
# Processing Record 49 of Set 2 | baruun-urt
# Processing Record 50 of Set 2 | cherskiy
# Processing Record 1 of Set 3 | bambous virieux
# Processing Record 2 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 3 of Set 3 | klaksvik
# Processing Record 4 of Set 3 | pisco
# Processing Record 5 of Set 3 | haines junction
# Processing Record 6 of Set 3 | dikson
# Processing Record 7 of Set 3 | bonthe
# Processing Record 8 of Set 3 | tabas
# Processing Record 9 of Set 3 | komsomolskiy
# Processing Record 10 of Set 3 | provideniya
# Processing Record 11 of Set 3 | banda aceh
# Processing Record 12 of Set 3 | naze
# Processing Record 13 of Set 3 | chumikan
# Processing Record 14 of Set 3 | mayo
# Processing Record 15 of Set 3 | port alfred
# Processing Record 16 of Set 3 | kyabe
# Processing Record 17 of Set 3 | goianesia
# Processing Record 18 of Set 3 | upernavik
# Processing Record 19 of Set 3 | norman wells
# Processing Record 20 of Set 3 | ler
# Processing Record 21 of Set 3 | kieta
# Processing Record 22 of Set 3 | tautira
# Processing Record 23 of Set 3 | qaanaaq
# Processing Record 24 of Set 3 | mount isa
# Processing Record 25 of Set 3 | vreed en hoop
# City not found. Skipping...
# Processing Record 26 of Set 3 | skiros
# City not found. Skipping...
# Processing Record 27 of Set 3 | tura
# Processing Record 28 of Set 3 | puerto escondido
# Processing Record 29 of Set 3 | gold coast
# Processing Record 30 of Set 3 | soto la marina
# Processing Record 31 of Set 3 | albany
# Processing Record 32 of Set 3 | adrar
# Processing Record 33 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 3 | chokurdakh
# Processing Record 35 of Set 3 | henties bay
# Processing Record 36 of Set 3 | tuatapere
# Processing Record 37 of Set 3 | bereda
# Processing Record 38 of Set 3 | kirakira
# Processing Record 39 of Set 3 | meulaboh
# Processing Record 40 of Set 3 | inuvik
# Processing Record 41 of Set 3 | nizhniy tsasuchey
# Processing Record 42 of Set 3 | trinidad
# Processing Record 43 of Set 3 | strelka
# Processing Record 44 of Set 3 | manosque
# Processing Record 45 of Set 3 | burnie
# Processing Record 46 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 47 of Set 3 | nueva gerona
# Processing Record 48 of Set 3 | lae
# Processing Record 49 of Set 3 | dingle
# Processing Record 50 of Set 3 | kodiak
# Processing Record 1 of Set 4 | hueyotlipan
# Processing Record 2 of Set 4 | zhigansk
# Processing Record 3 of Set 4 | lufilufi
# Processing Record 4 of Set 4 | cuamba
# Processing Record 5 of Set 4 | saint george
# Processing Record 6 of Set 4 | hyeres
# Processing Record 7 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 4 | hilo
# Processing Record 9 of Set 4 | hualmay
# Processing Record 10 of Set 4 | east london
# Processing Record 11 of Set 4 | panjwin
# City not found. Skipping...
# Processing Record 12 of Set 4 | abalak
# Processing Record 13 of Set 4 | broome
# Processing Record 14 of Set 4 | georgetown
# Processing Record 15 of Set 4 | sorland
# Processing Record 16 of Set 4 | kavieng
# Processing Record 17 of Set 4 | anori
# Processing Record 18 of Set 4 | mitsamiouli
# Processing Record 19 of Set 4 | kousseri
# Processing Record 20 of Set 4 | rantepao
# Processing Record 21 of Set 4 | vardo
# Processing Record 22 of Set 4 | berezovyy
# Processing Record 23 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 4 | bilma
# Processing Record 25 of Set 4 | okhotsk
# Processing Record 26 of Set 4 | tual
# Processing Record 27 of Set 4 | tocache
# Processing Record 28 of Set 4 | hami
# Processing Record 29 of Set 4 | jati
# Processing Record 30 of Set 4 | gander
# Processing Record 31 of Set 4 | asayita
# City not found. Skipping...
# Processing Record 32 of Set 4 | ternate
# Processing Record 33 of Set 4 | ovalle
# Processing Record 34 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 4 | najran
# Processing Record 36 of Set 4 | pevek
# Processing Record 37 of Set 4 | santa isabel do rio negro
# Processing Record 38 of Set 4 | saskylakh
# Processing Record 39 of Set 4 | santa maria
# Processing Record 40 of Set 4 | muros
# Processing Record 41 of Set 4 | port hedland
# Processing Record 42 of Set 4 | ranfurly
# Processing Record 43 of Set 4 | slave lake
# Processing Record 44 of Set 4 | uglovskoye
# Processing Record 45 of Set 4 | kananga
# Processing Record 46 of Set 4 | yar-sale
# Processing Record 47 of Set 4 | boa vista
# Processing Record 48 of Set 4 | kaya
# Processing Record 49 of Set 4 | clyde river
# Processing Record 50 of Set 4 | dunedin
# Processing Record 1 of Set 5 | horsham
# Processing Record 2 of Set 5 | masty
# Processing Record 3 of Set 5 | srednekolymsk
# Processing Record 4 of Set 5 | saint-philippe
# Processing Record 5 of Set 5 | aklavik
# Processing Record 6 of Set 5 | narsaq
# Processing Record 7 of Set 5 | lompoc
# Processing Record 8 of Set 5 | lima
# Processing Record 9 of Set 5 | thompson
# Processing Record 10 of Set 5 | avera
# Processing Record 11 of Set 5 | poum
# Processing Record 12 of Set 5 | fairbanks
# Processing Record 13 of Set 5 | atar
# Processing Record 14 of Set 5 | byron bay
# Processing Record 15 of Set 5 | ixtapa
# Processing Record 16 of Set 5 | rafaela
# Processing Record 17 of Set 5 | mildura
# Processing Record 18 of Set 5 | xihua
# Processing Record 19 of Set 5 | afonso claudio
# Processing Record 20 of Set 5 | santa cruz
# Processing Record 21 of Set 5 | vila franca do campo
# Processing Record 22 of Set 5 | cockburn town
# Processing Record 23 of Set 5 | bengkulu
# Processing Record 24 of Set 5 | mafinga
# Processing Record 25 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 5 | ilulissat
# Processing Record 27 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 5 | geraldton
# Processing Record 29 of Set 5 | zhezkazgan
# Processing Record 30 of Set 5 | buala
# Processing Record 31 of Set 5 | nantucket
# Processing Record 32 of Set 5 | faya
# Processing Record 33 of Set 5 | washington
# Processing Record 34 of Set 5 | la romana
# Processing Record 35 of Set 5 | darab
# Processing Record 36 of Set 5 | arawa
# Processing Record 37 of Set 5 | bontang
# Processing Record 38 of Set 5 | craigieburn
# Processing Record 39 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 40 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 5 | copperas cove
# Processing Record 42 of Set 5 | bohonye
# Processing Record 43 of Set 5 | whitianga
# Processing Record 44 of Set 5 | shahrud
# Processing Record 45 of Set 5 | inverness
# Processing Record 46 of Set 5 | imeni poliny osipenko
# Processing Record 47 of Set 5 | raudeberg
# Processing Record 48 of Set 5 | vologda
# Processing Record 49 of Set 5 | tazovskiy
# Processing Record 50 of Set 5 | nanlong
# Processing Record 1 of Set 6 | bethel
# Processing Record 2 of Set 6 | merauke
# Processing Record 3 of Set 6 | lagunas
# Processing Record 4 of Set 6 | turgenevo
# Processing Record 5 of Set 6 | tommot
# Processing Record 6 of Set 6 | xichang
# Processing Record 7 of Set 6 | biloela
# Processing Record 8 of Set 6 | dryden
# Processing Record 9 of Set 6 | noumea
# Processing Record 10 of Set 6 | popondetta
# Processing Record 11 of Set 6 | sitka
# Processing Record 12 of Set 6 | bolshoy lug
# Processing Record 13 of Set 6 | esmeraldas
# Processing Record 14 of Set 6 | dolores
# Processing Record 15 of Set 6 | sambava
# Processing Record 16 of Set 6 | salalah
# Processing Record 17 of Set 6 | cabo san lucas
# Processing Record 18 of Set 6 | viedma
# Processing Record 19 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 6 | makakilo city
# Processing Record 21 of Set 6 | svetlogorsk
# Processing Record 22 of Set 6 | synya
# Processing Record 23 of Set 6 | borgarnes
# Processing Record 24 of Set 6 | santa rosa
# Processing Record 25 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 6 | chama
# Processing Record 27 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 6 | katsuura
# Processing Record 29 of Set 6 | gambo
# Processing Record 30 of Set 6 | chuy
# Processing Record 31 of Set 6 | yining
# Processing Record 32 of Set 6 | mahebourg
# Processing Record 33 of Set 6 | naudero
# Processing Record 34 of Set 6 | alice springs
# Processing Record 35 of Set 6 | kaeo
# Processing Record 36 of Set 6 | mecca
# Processing Record 37 of Set 6 | khilok
# Processing Record 38 of Set 6 | maua
# Processing Record 39 of Set 6 | baragua
# Processing Record 40 of Set 6 | boden
# Processing Record 41 of Set 6 | nur
# Processing Record 42 of Set 6 | hastings
# Processing Record 43 of Set 6 | assiniboia
# Processing Record 44 of Set 6 | aksarka
# Processing Record 45 of Set 6 | havre-saint-pierre
# Processing Record 46 of Set 6 | tilichiki
# Processing Record 47 of Set 6 | longyearbyen
# Processing Record 48 of Set 6 | prince rupert
# Processing Record 49 of Set 6 | constitucion
# Processing Record 50 of Set 6 | porto walter
# Processing Record 1 of Set 7 | williamsburg
# Processing Record 2 of Set 7 | katima mulilo
# Processing Record 3 of Set 7 | nikolskoye
# Processing Record 4 of Set 7 | roald
# Processing Record 5 of Set 7 | murgab
# Processing Record 6 of Set 7 | martapura
# Processing Record 7 of Set 7 | laguna
# Processing Record 8 of Set 7 | nola
# Processing Record 9 of Set 7 | tecoanapa
# Processing Record 10 of Set 7 | ryotsu
# Processing Record 11 of Set 7 | kusti
# Processing Record 12 of Set 7 | fortuna
# Processing Record 13 of Set 7 | summerside
# Processing Record 14 of Set 7 | coquimbo
# Processing Record 15 of Set 7 | austin
# Processing Record 16 of Set 7 | kankan
# Processing Record 17 of Set 7 | uige
# Processing Record 18 of Set 7 | bilibino
# Processing Record 19 of Set 7 | praia
# Processing Record 20 of Set 7 | linxia
# Processing Record 21 of Set 7 | gizo
# Processing Record 22 of Set 7 | agar
# Processing Record 23 of Set 7 | maragogi
# Processing Record 24 of Set 7 | finschhafen
# Processing Record 25 of Set 7 | ponta do sol
# Processing Record 26 of Set 7 | venado tuerto
# Processing Record 27 of Set 7 | korostyshiv
# Processing Record 28 of Set 7 | ritchie
# Processing Record 29 of Set 7 | hofn
# Processing Record 30 of Set 7 | dukat
# Processing Record 31 of Set 7 | ahipara
# Processing Record 32 of Set 7 | ermoupolis
# Processing Record 33 of Set 7 | naliya
# Processing Record 34 of Set 7 | leningradskiy
# Processing Record 35 of Set 7 | pacifica
# Processing Record 36 of Set 7 | novomikhaylovskiy
# Processing Record 37 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 7 | bulgan
# Processing Record 39 of Set 7 | belaya gora
# Processing Record 40 of Set 7 | francisco beltrao
# Processing Record 41 of Set 7 | faanui
# Processing Record 42 of Set 7 | uruzgan
# Processing Record 43 of Set 7 | zverinogolovskoye
# Processing Record 44 of Set 7 | teya
# Processing Record 45 of Set 7 | fukuma
# Processing Record 46 of Set 7 | nome
# Processing Record 47 of Set 7 | mason city
# Processing Record 48 of Set 7 | mount gambier
# Processing Record 49 of Set 7 | ust-karsk
# Processing Record 50 of Set 7 | tanshui
# City not found. Skipping...
# Processing Record 1 of Set 8 | lata
# Processing Record 2 of Set 8 | paamiut
# Processing Record 3 of Set 8 | innisfail
# Processing Record 4 of Set 8 | keti bandar
# Processing Record 5 of Set 8 | kuytun
# Processing Record 6 of Set 8 | sembe
# Processing Record 7 of Set 8 | grinnell
# Processing Record 8 of Set 8 | tarancon
# Processing Record 9 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 10 of Set 8 | maxixe
# Processing Record 11 of Set 8 | shihezi
# Processing Record 12 of Set 8 | trojan
# Processing Record 13 of Set 8 | egvekinot
# Processing Record 14 of Set 8 | san andres
# Processing Record 15 of Set 8 | batman
# Processing Record 16 of Set 8 | fiumicino
# Processing Record 17 of Set 8 | shenjiamen
# Processing Record 18 of Set 8 | antsohihy
# Processing Record 19 of Set 8 | reconquista
# Processing Record 20 of Set 8 | saint anthony
# Processing Record 21 of Set 8 | isangel
# Processing Record 22 of Set 8 | moerai
# Processing Record 23 of Set 8 | new ulm
# Processing Record 24 of Set 8 | praia da vitoria
# Processing Record 25 of Set 8 | rigaud
# Processing Record 26 of Set 8 | conceicao da barra
# Processing Record 27 of Set 8 | orebro
# Processing Record 28 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 8 | rio grande
# Processing Record 30 of Set 8 | lakatoro
# Processing Record 31 of Set 8 | dzaoudzi
# Processing Record 32 of Set 8 | maralal
# Processing Record 33 of Set 8 | te anau
# Processing Record 34 of Set 8 | grindavik
# Processing Record 35 of Set 8 | victoria
# Processing Record 36 of Set 8 | rio gallegos
# Processing Record 37 of Set 8 | tuy hoa
# Processing Record 38 of Set 8 | berdigestyakh
# Processing Record 39 of Set 8 | yatou
# Processing Record 40 of Set 8 | awjilah
# Processing Record 41 of Set 8 | santa vitoria do palmar
# Processing Record 42 of Set 8 | luanda
# Processing Record 43 of Set 8 | boulder
# Processing Record 44 of Set 8 | muravlenko
# Processing Record 45 of Set 8 | leh
# Processing Record 46 of Set 8 | coihaique
# Processing Record 47 of Set 8 | nouadhibou
# Processing Record 48 of Set 8 | vestmanna
# Processing Record 49 of Set 8 | anadyr
# Processing Record 50 of Set 8 | ouagadougou
# Processing Record 1 of Set 9 | zeya
# Processing Record 2 of Set 9 | rawson
# Processing Record 3 of Set 9 | belyy yar
# Processing Record 4 of Set 9 | palmares
# Processing Record 5 of Set 9 | darhan
# Processing Record 6 of Set 9 | ekpoma
# Processing Record 7 of Set 9 | kurilsk
# Processing Record 8 of Set 9 | dongsheng
# Processing Record 9 of Set 9 | tutoia
# Processing Record 10 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 12 of Set 9 | luderitz
# Processing Record 13 of Set 9 | ust-nera
# Processing Record 14 of Set 9 | colac
# Processing Record 15 of Set 9 | marsh harbour
# Processing Record 16 of Set 9 | san carlos
# Processing Record 17 of Set 9 | nabire
# Processing Record 18 of Set 9 | matsubase
# Processing Record 19 of Set 9 | sao filipe
# Processing Record 20 of Set 9 | tahta
# Processing Record 21 of Set 9 | sayansk
# Processing Record 22 of Set 9 | dourdan
# Processing Record 23 of Set 9 | marystown
# Processing Record 24 of Set 9 | ust-ilimsk
# Processing Record 25 of Set 9 | lagoa
# Processing Record 26 of Set 9 | butte
# Processing Record 27 of Set 9 | mahajanga
# Processing Record 28 of Set 9 | wellington
# Processing Record 29 of Set 9 | narrabri
# Processing Record 30 of Set 9 | taltal
# Processing Record 31 of Set 9 | korla
# Processing Record 32 of Set 9 | jalu
# Processing Record 33 of Set 9 | esperance
# Processing Record 34 of Set 9 | myitkyina
# Processing Record 35 of Set 9 | codrington
# Processing Record 36 of Set 9 | nanortalik
# Processing Record 37 of Set 9 | asfi
# Processing Record 38 of Set 9 | omboue
# Processing Record 39 of Set 9 | charters towers
# Processing Record 40 of Set 9 | klyuchi
# Processing Record 41 of Set 9 | teguldet
# Processing Record 42 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 43 of Set 9 | chicama
# Processing Record 44 of Set 9 | borovoy
# Processing Record 45 of Set 9 | trelew
# Processing Record 46 of Set 9 | guerrero negro
# Processing Record 47 of Set 9 | kalmunai
# Processing Record 48 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 49 of Set 9 | batagay-alyta
# Processing Record 50 of Set 9 | mehamn
# Processing Record 1 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 3 of Set 10 | cayenne
# Processing Record 4 of Set 10 | nalut
# Processing Record 5 of Set 10 | belomorsk
# Processing Record 6 of Set 10 | hamilton
# Processing Record 7 of Set 10 | himora
# City not found. Skipping...
# Processing Record 8 of Set 10 | erenhot
# Processing Record 9 of Set 10 | shingu
# Processing Record 10 of Set 10 | kavant
# City not found. Skipping...
# Processing Record 11 of Set 10 | miraflores
# Processing Record 12 of Set 10 | tasiilaq
# Processing Record 13 of Set 10 | brae
# Processing Record 14 of Set 10 | mikkeli
# Processing Record 15 of Set 10 | chardara
# Processing Record 16 of Set 10 | zabaykalsk
# Processing Record 17 of Set 10 | arman
# Processing Record 18 of Set 10 | kupino
# Processing Record 19 of Set 10 | shelburne
# Processing Record 20 of Set 10 | aguimes
# Processing Record 21 of Set 10 | kuandian
# Processing Record 22 of Set 10 | khuzdar
# Processing Record 23 of Set 10 | tsilna
# Processing Record 24 of Set 10 | voh
# Processing Record 25 of Set 10 | hervey bay
# Processing Record 26 of Set 10 | pedernales
# Processing Record 27 of Set 10 | satipo
# Processing Record 28 of Set 10 | altus
# Processing Record 29 of Set 10 | erzin
# Processing Record 30 of Set 10 | gangoh
# Processing Record 31 of Set 10 | cidreira
# Processing Record 32 of Set 10 | costa rica
# Processing Record 33 of Set 10 | pochutla
# Processing Record 34 of Set 10 | mayya
# Processing Record 35 of Set 10 | uray
# Processing Record 36 of Set 10 | olafsvik
# Processing Record 37 of Set 10 | mnogovershinnyy
# Processing Record 38 of Set 10 | hamadan
# Processing Record 39 of Set 10 | iracoubo
# Processing Record 40 of Set 10 | tungkang
# City not found. Skipping...
# Processing Record 41 of Set 10 | angoram
# Processing Record 42 of Set 10 | kuryk
# Processing Record 43 of Set 10 | flinders
# Processing Record 44 of Set 10 | sarangani
# Processing Record 45 of Set 10 | galle
# Processing Record 46 of Set 10 | hay river
# Processing Record 47 of Set 10 | podgornoye
# Processing Record 48 of Set 10 | kungurtug
# Processing Record 49 of Set 10 | saveh
# Processing Record 50 of Set 10 | willowmore
# Processing Record 1 of Set 11 | maniitsoq
# Processing Record 2 of Set 11 | nova ushytsya
# Processing Record 3 of Set 11 | savannah bight
# Processing Record 4 of Set 11 | fairlie
# Processing Record 5 of Set 11 | selfoss
# Processing Record 6 of Set 11 | lincoln
# Processing Record 7 of Set 11 | umm kaddadah
# Processing Record 8 of Set 11 | kalur kot
# Processing Record 9 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 10 of Set 11 | mizan teferi
# Processing Record 11 of Set 11 | biak
# Processing Record 12 of Set 11 | kataysk
# Processing Record 13 of Set 11 | agboville
# Processing Record 14 of Set 11 | sao joao da ponte
# Processing Record 15 of Set 11 | atasu
# Processing Record 16 of Set 11 | husavik
# Processing Record 17 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 11 | gravdal
# Processing Record 19 of Set 11 | belaya
# Processing Record 20 of Set 11 | kaikalur
# Processing Record 21 of Set 11 | asau
# Processing Record 22 of Set 11 | handwara
# City not found. Skipping...
# Processing Record 23 of Set 11 | tucumcari
# Processing Record 24 of Set 11 | port hardy
# Processing Record 25 of Set 11 | meadow lake
# Processing Record 26 of Set 11 | kiambu
# Processing Record 27 of Set 11 | lasa
# Processing Record 28 of Set 11 | camana
# Processing Record 29 of Set 11 | toora-khem
# Processing Record 30 of Set 11 | ufa
# Processing Record 31 of Set 11 | skovorodino
# Processing Record 32 of Set 11 | manuk mangkaw
# Processing Record 33 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 11 | harindanga
# Processing Record 35 of Set 11 | areosa
# Processing Record 36 of Set 11 | carroll
# Processing Record 37 of Set 11 | calbuco
# Processing Record 38 of Set 11 | santa maria del oro
# Processing Record 39 of Set 11 | san rafael
# Processing Record 40 of Set 11 | sirnak
# Processing Record 41 of Set 11 | bandundu
# Processing Record 42 of Set 11 | plettenberg bay
# Processing Record 43 of Set 11 | lavrentiya
# Processing Record 44 of Set 11 | pemangkat
# Processing Record 45 of Set 11 | ranong
# Processing Record 46 of Set 11 | iskateley
# Processing Record 47 of Set 11 | huasahuasi
# Processing Record 48 of Set 11 | cururupu
# Processing Record 49 of Set 11 | acapulco
# Processing Record 50 of Set 11 | antalaha
# Processing Record 1 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 2 of Set 12 | ningxiang
# Processing Record 3 of Set 12 | labuhan
# Processing Record 4 of Set 12 | vila
# Processing Record 5 of Set 12 | puerto del rosario
# Processing Record 6 of Set 12 | olinda
# Processing Record 7 of Set 12 | san juan
# Processing Record 8 of Set 12 | ozinki
# Processing Record 9 of Set 12 | edd
# Processing Record 10 of Set 12 | killybegs
# Processing Record 11 of Set 12 | utiel
# Processing Record 12 of Set 12 | deyang
# Processing Record 13 of Set 12 | akureyri
# Processing Record 14 of Set 12 | flin flon
# Processing Record 15 of Set 12 | kansanshi
# Processing Record 16 of Set 12 | kenai
# Processing Record 17 of Set 12 | vanderhoof
# Processing Record 18 of Set 12 | odienne
# Processing Record 19 of Set 12 | anchorage
# Processing Record 20 of Set 12 | basco
# Processing Record 21 of Set 12 | ugoofaaru
# Processing Record 22 of Set 12 | flensburg
# Processing Record 23 of Set 12 | ariquemes
# Processing Record 24 of Set 12 | kingseat
# Processing Record 25 of Set 12 | beyneu
# Processing Record 26 of Set 12 | vanavara
# Processing Record 27 of Set 12 | rio branco do sul
# Processing Record 28 of Set 12 | jibuti
# Processing Record 29 of Set 12 | zhuhai
# Processing Record 30 of Set 12 | vila velha
# Processing Record 31 of Set 12 | nalvo
# Processing Record 32 of Set 12 | kobyzhcha
# Processing Record 33 of Set 12 | impfondo
# Processing Record 34 of Set 12 | saryg-sep
# Processing Record 35 of Set 12 | tessalit
# Processing Record 36 of Set 12 | nuoro
# Processing Record 37 of Set 12 | iquitos
# Processing Record 38 of Set 12 | half moon bay
# Processing Record 39 of Set 12 | bardiyah
# Processing Record 40 of Set 12 | skawina
# Processing Record 41 of Set 12 | porto novo
# Processing Record 42 of Set 12 | la palma
# Processing Record 43 of Set 12 | broken hill
# Processing Record 44 of Set 12 | kununurra
# Processing Record 45 of Set 12 | pangnirtung
# Processing Record 46 of Set 12 | loandjili
# Processing Record 47 of Set 12 | matagami
# Processing Record 48 of Set 12 | shetpe
# Processing Record 49 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 50 of Set 12 | ojinaga
# Processing Record 1 of Set 13 | suluova
# Processing Record 2 of Set 13 | utiroa
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0     Kormilovka      RU  55.00   74.10     50.00       100          58
# 1    New Norfolk      AU -42.78  147.06     50.00        53          75
# 2      Omsukchan      RU  62.53  155.80     36.27        88         100
# 3          Gamba      GA  -2.65   10.00     72.73        85         100
# 4          Luwuk      ID  -0.95  122.79     83.66        58         100
# ..           ...     ...    ...     ...       ...       ...         ...
# 553    Loandjili      CG  -4.76   11.86     75.20        83          90
# 554     Matagami      CA  49.75  -77.63     59.00        67           1
# 555       Shetpe      KZ  44.17   52.12     65.84        61          97
# 556      Ojinaga      MX  29.57 -104.42     96.80        19           1
# 557      Suluova      TR  40.83   35.65     55.40        76           0
#
#      Wind Speed Current Description  Rain(inches)  Snow(inches)
# 0          4.47                 fog             0             0
# 1         11.41       broken clouds             0             0
# 2          7.70     overcast clouds             0             0
# 3          6.73     overcast clouds             0             0
# 4          4.41     overcast clouds             0             0
# ..          ...                 ...           ...           ...
# 553        3.36     overcast clouds             0             0
# 554        4.65           clear sky             0             0
# 555        8.32     overcast clouds             0             0
# 556       13.87           clear sky             0             0
# 557        2.24           clear sky             0             0
#
# [558 rows x 11 columns]

# %%
#Find how many cities rain in last 3 hours
rain=city_data_df.loc[city_data_df["Rain(inches)"]>0]
len(rain)
# Out:
# 0

# %%
#Find how many cities snow in last 3 hours
snow=city_data_df.loc[city_data_df["Snow(inches)"]>0]
len(snow)
# Out:
# 0

# %%
# Create the output file (CSV).
output_data_file = "data/WeatherPy_challenge.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="weather")
